# %%
# !pip install av -f https://download.pytorch.org/whl/cu118
# Out:
# Looking in links: https://download.pytorch.org/whl/cu118
# ...

# %%
# !python3 -m pip install -U git+https://github.com/facebookresearch/audiocraft#egg=audiocraft --no-deps
# Out:
# ...
#   Cloning https://github.com/facebookresearch/audiocraft to /tmp/pip-install-t4xmvbqo/audiocraft_376830f0ea5845c2973119e5a477f85e
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/audiocraft /tmp/pip-install-t4xmvbqo/audiocraft_376830f0ea5845c2973119e5a477f85e
#   Resolved https://github.com/facebookresearch/audiocraft to commit 896ec7c47f5e5d1e5aa1e4b260c4405328bf009d
#   Preparing metadata (setup.py) ... done

# %%
# !pip install julius

# %%
# !pip install xformers

# %%
# !pip install flashy

# %%
# !pip install num2words

# %%
# !pip install torchdiffeq

# %%
# !pip install torchmetrics

# %%
from audiocraft.models import musicgen
from audiocraft.utils.notebook import display_audio
import torch

# %%
import audiocraft
from audiocraft.models import loaders
import functools

def patched_get_state_dict(file_or_url_or_id, filename="state_dict.bin", device='cpu', cache_dir=None,
                           _original_get_state_dict=None):
    # Call the original function, but without the library_version and library_name arguments
    return _original_get_state_dict(file_or_url_or_id, filename=filename, device=device, cache_dir=cache_dir)

# Patch the function
loaders._get_state_dict = functools.partial(patched_get_state_dict,
                                             _original_get_state_dict=loaders._get_state_dict)

print("audiocraft.models.loaders._get_state_dict has been patched.")
# Out:
# audiocraft.models.loaders._get_state_dict has been patched.

# %%
model = musicgen.MusicGen.get_pretrained('medium', device='cuda')
model.set_generation_params(duration=8)
# Out:
# /usr/local/lib/python3.12/dist-packages/audiocraft/models/musicgen.py:83: UserWarning: MusicGen pretrained model relying on deprecated checkpoint mapping. Please use full pre-trained id instead: facebook/musicgen-medium
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# state_dict.bin:   0%|          | 0.00/3.68G [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# ...

# %%
res = model.generate([
    'Generate an Indian-style EDM like Martin Garrix.'
],
    progress=True)
display_audio(res, 32000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os
import soundfile as sf
output_folder = "output"
os.makedirs(output_folder, exist_ok=True)
output_path = os.path.join(output_folder, "edm_track.wav")
sf.write(output_path, res.cpu().squeeze(), 32000)

print(f"Audio saved to {output_path}")
# Out:
# Audio saved to output/edm_track.wav
